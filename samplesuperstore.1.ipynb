# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
print(os.getcwd())
# inorder to change directory for direct upload
#os.chdir(C:\Users\LENOVO\Downloads)
# Out:
# C:\Users\LENOVO

# %%
df=pd.read_csv('SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
vis1 = sns.barplot(x="Region",y="Profit",data=df,hue="Segment")
vis1
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
vis2=sns.barplot(x="Segment",y="Profit",data=df,hue="Region")

# %%
vis3=sns.barplot(x="Segment",y="Sales",data=df,hue="Region")
vis3
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
vis4=sns.barplot(x="Region",y="Sales",data=df,hue="Segment")
vis4
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
vis5=sns.barplot(x="Region",y="Sales",data=df,hue="Ship Mode")
vis5
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
vis5=sns.barplot(x="Ship Mode",y="Sales",data=df,hue="Region")
vis5
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
vis6=sns.barplot(x="Ship Mode",y="Sales",data=df,hue="Segment")
vis6
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
vis7=sns.barplot(x="Segment",y="Sales",data=df,hue="Ship Mode")
vis7
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
vis8=sns.barplot(x='Segment',y='Profit',data=df,hue='Ship Mode')
vis8
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Profit'>

# %%
vis9=sns.barplot(x='Region',y='Profit',data=df,hue='Ship Mode')
vis9
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
vis10=sns.barplot(x='State',y='Profit',data=df,hue='Ship Mode')
vis10
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
vis10=sns.violinplot(x='State',y='Profit',data=df,hue='Ship Mode')
vis10
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
vis11=sns.boxplot(x='State',y='Profit',data=df,hue='Ship Mode')
vis11
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
vis12=sns.stripplot(x='State',y='Profit',data=df,hue='Ship Mode')
vis12
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
g_h = sns.FacetGrid(df,row="Region",col="Segment",palette="Set1")
g_h = g_h.map(plt.hist,"Profit")

# %%
g= sns.FacetGrid(df,row="Region",col="Segment",hue="Ship Mode",palette="Set1")
kws = dict(s=50,linewidth=0.5,edgecolor="black")
g= g.map(plt.scatter,"Sales","Profit",**kws)

# %%
g= sns.FacetGrid(df,row="Region",col="Segment")
kws = dict(s=50,linewidth=0.5,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(15,70),ylim=(0,22))

# %%
g= sns.FacetGrid(df,row="Region",col="Segment",hue="Ship Mode")
kws = dict(s=50,linewidth=0.5,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(15,70),ylim=(0,22))

# %%
g= sns.FacetGrid(df,row="Region",col="Segment",hue="Ship Mode",palette="Set1")
kws = dict(s=50,linewidth=0.5,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(0,80),ylim=(0,30))
for ax in g.axes.flat:
    ax.plot((0,80),(0,30),c="orange",ls="--")
g.add_legend()

# %%
g= sns.FacetGrid(df,row="Region",col="Ship Mode",hue="Segment",palette="Set1")
kws = dict(s=50,linewidth=0.5,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(0,80),ylim=(0,30))
for ax in g.axes.flat:
    ax.plot((0,80),(0,30),c="orange",ls="--")
g.add_legend()

# %%
sns.barplot(x='City',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.violinplot(x='City',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.boxplot(x='City',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.stripplot(x='City',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.stripplot(x='City',y='Sales',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Sales'>
